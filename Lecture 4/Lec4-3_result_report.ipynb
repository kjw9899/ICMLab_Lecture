# %%
# !mkdir results
# !ls
# !ls results
# Out:
# mkdir: `results' 디렉토리를 만들 수 없습니다: 파일이 있습니다
#  Lab6_result_report.ipynb  'Practice Json.ipynb'   data   results   test.json

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import argparse
import numpy as np
import time
from copy import deepcopy # Add Deepcopy for args

# %% [markdown]
# ## Data preparation

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainset, valset = torch.utils.data.random_split(trainset, [40000, 10000])
testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
partition = {'train': trainset, 'val':valset, 'test':testset}
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Model Architecture

# %%
class MLP(nn.Module):
    def __init__(self, in_dim, out_dim, hid_dim, n_layer, act, dropout, use_bn, use_xavier):
        super(MLP, self).__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.hid_dim = hid_dim
        self.n_layer = n_layer
        self.act = act
        self.dropout = dropout
        self.use_bn = use_bn
        self.use_xavier = use_xavier
        
        # ====== Create Linear Layers ====== #
        self.fc1 = nn.Linear(self.in_dim, self.hid_dim)
        
        self.linears = nn.ModuleList()
        self.bns = nn.ModuleList()
        for i in range(self.n_layer-1):
            self.linears.append(nn.Linear(self.hid_dim, self.hid_dim))
            if self.use_bn:
                self.bns.append(nn.BatchNorm1d(self.hid_dim))
                
        self.fc2 = nn.Linear(self.hid_dim, self.out_dim)
        
        # ====== Create Activation Function ====== #
        if self.act == 'relu':
            self.act = nn.ReLU()
        elif self.act == 'tanh':
            self.act == nn.Tanh()
        elif self.act == 'sigmoid':
            self.act = nn.Sigmoid()
        else:
            raise ValueError('no valid activation function selected!')
        
        # ====== Create Regularization Layer ======= #
        self.dropout = nn.Dropout(self.dropout)
        if self.use_xavier:
            self.xavier_init()
          
    def forward(self, x):
        x = self.act(self.fc1(x))
        for i in range(len(self.linears)):
            x = self.act(self.linears[i](x))
            x = self.bns[i](x)
            x = self.dropout(x)
        x = self.fc2(x)
        return x
    
    def xavier_init(self):
        for linear in self.linears:
            nn.init.xavier_normal_(linear.weight)
            linear.bias.data.fill_(0.01)
            
net = MLP(3072, 10, 100, 4, 'relu', 0.1, True, True) # Testing Model Construction

# %% [markdown]
# ## Train, Validation, Test and Experiment

# %%
def train(net, partition, optimizer, criterion, args):
    trainloader = torch.utils.data.DataLoader(partition['train'], 
                                              batch_size=args.train_batch_size, 
                                              shuffle=True, num_workers=2)
    net.train()

    correct = 0
    total = 0
    train_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        optimizer.zero_grad() # [21.01.05 오류 수정] 매 Epoch 마다 .zero_grad()가 실행되는 것을 매 iteration 마다 실행되도록 수정했습니다. 

        # get the inputs
        inputs, labels = data
        inputs = inputs.view(-1, 3072)
        inputs = inputs.cuda()
        labels = labels.cuda()
        outputs = net(inputs)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = train_loss / len(trainloader)
    train_acc = 100 * correct / total
    return net, train_loss, train_acc

# %%
def validate(net, partition, criterion, args):
    valloader = torch.utils.data.DataLoader(partition['val'], 
                                            batch_size=args.test_batch_size, 
                                            shuffle=False, num_workers=2)
    net.eval()

    correct = 0
    total = 0
    val_loss = 0 
    with torch.no_grad():
        for data in valloader:
            images, labels = data
            images = images.view(-1, 3072)
            images = images.cuda()
            labels = labels.cuda()
            outputs = net(images)

            loss = criterion(outputs, labels)
            
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        val_loss = val_loss / len(valloader)
        val_acc = 100 * correct / total
    return val_loss, val_acc

# %%
def test(net, partition, args):
    testloader = torch.utils.data.DataLoader(partition['test'], 
                                             batch_size=args.test_batch_size, 
                                             shuffle=False, num_workers=2)
    net.eval()
    
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images = images.view(-1, 3072)
            images = images.cuda()
            labels = labels.cuda()

            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        test_acc = 100 * correct / total
    return test_acc

# %%
def experiment(partition, args):
  
    net = MLP(args.in_dim, args.out_dim, args.hid_dim, args.n_layer, args.act, args.dropout, args.use_bn, args.use_xavier)
    net.cuda()

    criterion = nn.CrossEntropyLoss()
    if args.optim == 'SGD':
        optimizer = optim.RMSprop(net.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'RMSprop':
        optimizer = optim.RMSprop(net.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'Adam':
        optimizer = optim.Adam(net.parameters(), lr=args.lr, weight_decay=args.l2)
    else:
        raise ValueError('In-valid optimizer choice')
    
    # ===== List for epoch-wise data ====== #
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []
    # ===================================== #
        
    for epoch in range(args.epoch):  # loop over the dataset multiple times
        ts = time.time()
        net, train_loss, train_acc = train(net, partition, optimizer, criterion, args)
        val_loss, val_acc = validate(net, partition, criterion, args)
        te = time.time()
        
        # ====== Add Epoch Data ====== #
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)
        # ============================ #
        
        print('Epoch {}, Acc(train/val): {:2.2f}/{:2.2f}, Loss(train/val) {:2.2f}/{:2.2f}. Took {:2.2f} sec'.format(epoch, train_acc, val_acc, train_loss, val_loss, te-ts))
        
    test_acc = test(net, partition, args)    
    
    # ======= Add Result to Dictionary ======= #
    result = {}
    result['train_losses'] = train_losses
    result['val_losses'] = val_losses
    result['train_accs'] = train_accs
    result['val_accs'] = val_accs
    result['train_acc'] = train_acc
    result['val_acc'] = val_acc
    result['test_acc'] = test_acc
    return vars(args), result
    # ===================================== #

# %% [markdown]
# ## Manage Experiment Results

# %%
import hashlib
import json
from os import listdir
from os.path import isfile, join
import pandas as pd

def save_exp_result(setting, result):
    exp_name = setting['exp_name']
    del setting['epoch']
    del setting['test_batch_size'] ## epoch, batch_size는 실험에 영향을 미치지 않는 변수이기 때문에 삭제

    hash_key = hashlib.sha1(str(setting).encode()).hexdigest()[:6]
    filename = './results/{}-{}.json'.format(exp_name, hash_key)
    result.update(setting) ## result라는 dic에 setting도 합치기 위함
    with open(filename, 'w') as f:
        json.dump(result, f)

    
def load_exp_result(exp_name):
    dir_path = './results'
    filenames = [f for f in listdir(dir_path) if isfile(join(dir_path, f)) if '.json' in f]
    list_result = []
    for filename in filenames:
        if exp_name in filename:
            with open(join(dir_path, filename), 'r') as infile:
                results = json.load(infile)
                list_result.append(results)
    df = pd.DataFrame(list_result) # .drop(columns=[])
    return df

# %%
# ====== Random Seed Initialization ====== #
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")
args.exp_name = "exp1_n_layer_hid_dim"

# ====== Model Capacity ====== #
args.in_dim = 3072
args.out_dim = 10
args.hid_dim = 100
args.act = 'relu'

# ====== Regularization ======= #
args.dropout = 0.2
args.use_bn = True
args.l2 = 0.00001
args.use_xavier = True

# ====== Optimizer & Training ====== #
args.optim = 'RMSprop' #'RMSprop' #SGD, RMSprop, ADAM...
args.lr = 0.0015
args.epoch = 10

args.train_batch_size = 256
args.test_batch_size = 1024

# ====== Experiment Variable ====== #
name_var1 = 'n_layer'
name_var2 = 'hid_dim'
list_var1 = [1, 2, 3]
list_var2 = [500, 300]


for var1 in list_var1:
    for var2 in list_var2:
        setattr(args, name_var1, var1) ## args.name_var1 = var1 과 같은 말
        setattr(args, name_var2, var2)
        print(args)
                
        setting, result = experiment(partition, deepcopy(args))
        save_exp_result(setting, result)
# Out:
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp1_n_layer_hid_dim', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.0015, n_layer=1, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 37.93/40.11, Loss(train/val) 2.39/1.76. Took 3.32 sec
# Epoch 1, Acc(train/val): 46.06/40.14, Loss(train/val) 1.56/1.88. Took 3.38 sec
# Epoch 2, Acc(train/val): 48.86/38.09, Loss(train/val) 1.49/1.95. Took 3.31 sec
# Epoch 3, Acc(train/val): 51.05/41.65, Loss(train/val) 1.44/1.91. Took 3.29 sec
# Epoch 4, Acc(train/val): 53.55/41.94, Loss(train/val) 1.37/1.92. Took 3.34 sec
# Epoch 5, Acc(train/val): 54.81/40.10, Loss(train/val) 1.32/2.17. Took 3.34 sec
# Epoch 6, Acc(train/val): 56.70/48.40, Loss(train/val) 1.29/1.51. Took 3.32 sec
# Epoch 7, Acc(train/val): 58.38/45.90, Loss(train/val) 1.23/1.68. Took 3.36 sec
# Epoch 8, Acc(train/val): 59.91/36.88, Loss(train/val) 1.20/2.59. Took 3.38 sec
# Epoch 9, Acc(train/val): 61.64/48.18, Loss(train/val) 1.15/1.63. Took 3.36 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp1_n_layer_hid_dim', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0015, n_layer=1, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 38.55/36.19, Loss(train/val) 2.19/2.08. Took 3.34 sec
# Epoch 1, Acc(train/val): 46.49/39.83, Loss(train/val) 1.54/1.83. Took 3.36 sec
# Epoch 2, Acc(train/val): 49.23/44.51, Loss(train/val) 1.47/1.64. Took 3.35 sec
# Epoch 3, Acc(train/val): 51.50/45.96, Loss(train/val) 1.40/1.56. Took 3.30 sec
# Epoch 4, Acc(train/val): 53.47/47.96, Loss(train/val) 1.35/1.57. Took 3.33 sec
# Epoch 5, Acc(train/val): 55.65/43.28, Loss(train/val) 1.29/1.75. Took 3.33 sec
# Epoch 6, Acc(train/val): 56.60/42.21, Loss(train/val) 1.26/1.93. Took 3.37 sec
# Epoch 7, Acc(train/val): 59.07/47.36, Loss(train/val) 1.21/1.66. Took 3.37 sec
# Epoch 8, Acc(train/val): 59.89/44.84, Loss(train/val) 1.18/1.74. Took 3.34 sec
# Epoch 9, Acc(train/val): 61.49/45.58, Loss(train/val) 1.14/1.88. Took 3.30 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp1_n_layer_hid_dim', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.0015, n_layer=2, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 37.47/38.55, Loss(train/val) 1.79/1.81. Took 3.41 sec
# Epoch 1, Acc(train/val): 46.26/37.24, Loss(train/val) 1.51/1.96. Took 3.38 sec
# Epoch 2, Acc(train/val): 50.13/43.15, Loss(train/val) 1.42/1.61. Took 3.35 sec
# Epoch 3, Acc(train/val): 52.73/46.76, Loss(train/val) 1.33/1.49. Took 3.38 sec
# Epoch 4, Acc(train/val): 55.52/41.89, Loss(train/val) 1.26/1.83. Took 3.32 sec
# Epoch 5, Acc(train/val): 57.68/44.63, Loss(train/val) 1.20/1.73. Took 3.33 sec
# Epoch 6, Acc(train/val): 59.86/51.97, Loss(train/val) 1.13/1.39. Took 3.37 sec
# Epoch 7, Acc(train/val): 61.65/45.35, Loss(train/val) 1.08/1.71. Took 3.34 sec
# Epoch 8, Acc(train/val): 63.86/51.67, Loss(train/val) 1.02/1.50. Took 3.35 sec
# Epoch 9, Acc(train/val): 66.17/49.88, Loss(train/val) 0.96/1.53. Took 3.39 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp1_n_layer_hid_dim', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0015, n_layer=2, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 37.52/41.10, Loss(train/val) 1.76/1.69. Took 3.31 sec
# Epoch 1, Acc(train/val): 46.24/43.56, Loss(train/val) 1.52/1.62. Took 3.36 sec
# Epoch 2, Acc(train/val): 49.94/43.29, Loss(train/val) 1.41/1.66. Took 3.31 sec
# Epoch 3, Acc(train/val): 52.69/47.36, Loss(train/val) 1.34/1.55. Took 3.33 sec
# Epoch 4, Acc(train/val): 54.46/49.55, Loss(train/val) 1.29/1.48. Took 3.36 sec
# Epoch 5, Acc(train/val): 56.98/48.87, Loss(train/val) 1.22/1.56. Took 3.40 sec
# Epoch 6, Acc(train/val): 59.16/50.01, Loss(train/val) 1.16/1.47. Took 3.32 sec
# Epoch 7, Acc(train/val): 61.31/49.38, Loss(train/val) 1.11/1.54. Took 3.39 sec
# Epoch 8, Acc(train/val): 62.70/45.14, Loss(train/val) 1.06/1.78. Took 3.35 sec
# Epoch 9, Acc(train/val): 63.84/50.37, Loss(train/val) 1.02/1.46. Took 3.39 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp1_n_layer_hid_dim', hid_dim=500, in_dim=3072, l2=1e-05, lr=0.0015, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 34.75/38.69, Loss(train/val) 1.86/1.75. Took 3.34 sec
# Epoch 1, Acc(train/val): 44.72/39.42, Loss(train/val) 1.55/1.69. Took 3.40 sec
# Epoch 2, Acc(train/val): 49.04/43.79, Loss(train/val) 1.42/1.57. Took 3.39 sec
# Epoch 3, Acc(train/val): 52.40/41.59, Loss(train/val) 1.33/1.79. Took 3.38 sec
# Epoch 4, Acc(train/val): 55.11/47.03, Loss(train/val) 1.26/1.54. Took 3.36 sec
# Epoch 5, Acc(train/val): 57.51/49.82, Loss(train/val) 1.18/1.43. Took 3.37 sec
# Epoch 6, Acc(train/val): 59.53/48.79, Loss(train/val) 1.13/1.55. Took 3.35 sec
# Epoch 7, Acc(train/val): 61.44/49.46, Loss(train/val) 1.07/1.54. Took 3.45 sec
# Epoch 8, Acc(train/val): 63.72/50.53, Loss(train/val) 1.01/1.45. Took 3.36 sec
# Epoch 9, Acc(train/val): 65.61/50.10, Loss(train/val) 0.96/1.59. Took 3.36 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp1_n_layer_hid_dim', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0015, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 36.34/38.81, Loss(train/val) 1.77/1.72. Took 3.36 sec
# Epoch 1, Acc(train/val): 45.90/45.97, Loss(train/val) 1.51/1.49. Took 3.40 sec
# Epoch 2, Acc(train/val): 50.05/40.39, Loss(train/val) 1.39/1.76. Took 3.34 sec
# Epoch 3, Acc(train/val): 52.72/44.18, Loss(train/val) 1.32/1.64. Took 3.35 sec
# Epoch 4, Acc(train/val): 55.20/50.55, Loss(train/val) 1.25/1.39. Took 3.37 sec
# Epoch 5, Acc(train/val): 57.63/47.27, Loss(train/val) 1.19/1.56. Took 3.36 sec
# Epoch 6, Acc(train/val): 59.60/45.69, Loss(train/val) 1.13/1.61. Took 3.34 sec
# Epoch 7, Acc(train/val): 61.33/49.94, Loss(train/val) 1.08/1.46. Took 3.37 sec
# Epoch 8, Acc(train/val): 63.13/50.12, Loss(train/val) 1.03/1.51. Took 3.37 sec
# Epoch 9, Acc(train/val): 65.06/49.66, Loss(train/val) 0.98/1.55. Took 3.34 sec

# %%
# !ls results
# Out:
# exp1_n_layer_hid_dim-41b634.json  exp1_n_layer_hid_dim-bfc899.json
# exp1_n_layer_hid_dim-61a2d0.json  exp1_n_layer_hid_dim-cab8c1.json
# exp1_n_layer_hid_dim-7b70fe.json  exp1_n_layer_hid_dim-dece45.json

# %%
# !cat results/exp1_n_layer_hid_dim-41b634.json
# Out:
# {"train_losses": [1.771469005353891, 1.511117148551212, 1.3933063912543522, 1.3230268484467913, 1.2527304341079324, 1.1940960436110284, 1.1340343071396943, 1.082287361287767, 1.0271685385400322, 0.98241188609676], "val_losses": [1.7214785099029541, 1.4902804374694825, 1.7634827256202699, 1.6370152831077576, 1.3871952652931214, 1.5624906778335572, 1.614415740966797, 1.4591437935829163, 1.5096706032752991, 1.5497953176498414], "train_accs": [36.3375, 45.9, 50.0525, 52.72, 55.1975, 57.6275, 59.6, 61.3275, 63.135, 65.0575], "val_accs": [38.81, 45.97, 40.39, 44.18, 50.55, 47.27, 45.69, 49.94, 50.12, 49.66], "train_acc": 65.0575, "val_acc": 49.66, "test_acc": 49.89, "exp_name": "exp1_n_layer_hid_dim", "in_dim": 3072, "out_dim": 10, "hid_dim": 300, "act": "relu", "dropout": 0.2, "use_bn": true, "l2": 1e-05, "use_xavier": true, "optim": "RMSprop", "lr": 0.0015, "train_batch_size": 256, "n_layer": 3}

# %%
print(type(load_exp_result('exp1')))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
result=load_exp_result('exp1')

import seaborn as sns


sns.barplot(x='n_layer',y='test_acc',hue='hid_dim',data=result) ## hue는 계열 또는 범례를 뜻한다.
# Out:
# <AxesSubplot:xlabel='n_layer', ylabel='test_acc'>

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

df = load_exp_result('exp1')

fig, ax = plt.subplots(1, 3)
fig.set_size_inches(15, 6)
sns.set_style("darkgrid", {"axes.facecolor": ".9"})

sns.barplot(x='n_layer', y='train_acc', hue='hid_dim', data=df, ax=ax[0])
sns.barplot(x='n_layer', y='val_acc', hue='hid_dim', data=df, ax=ax[1])
sns.barplot(x='n_layer', y='test_acc', hue='hid_dim', data=df, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='n_layer', ylabel='test_acc'>

# %%
var1 = 'n_layer'
var2 = 'hid_dim'

df = load_exp_result('exp1')
list_v1 = df[var1].unique()
list_v2 = df[var2].unique()
print(list_v1, list_v2)
list_data = []

for value1 in list_v1:
    for value2 in list_v2:
        row = df.loc[df[var1]==value1]
        row = row.loc[df[var2]==value2]
        
        
        train_losses = list(row.train_losses)[0]
        val_losses = list(row.val_losses)[0]
        
        for epoch, train_loss in enumerate(train_losses):
            list_data.append({'type':'train', 'loss':train_loss, 'epoch':epoch, var1:value1, var2:value2})
        for epoch, val_loss in enumerate(val_losses):
            list_data.append({'type':'val', 'loss':val_loss, 'epoch':epoch, var1:value1, var2:value2})
        
df = pd.DataFrame(list_data)
g = sns.FacetGrid(df, row=var2, col=var1, hue='type', margin_titles=True, sharey=False)
g = g.map(plt.plot, 'epoch', 'loss', marker='.')
g.add_legend()
g.fig.suptitle('Train loss vs Val loss')
plt.subplots_adjust(top=0.89)
# Out:
# [1 2 3] [300 500]
# 1 300                                         train_losses  \
# 0  [2.1944318584575773, 1.538207830137508, 1.4708...
#
#                                           val_losses  \
# 0  [2.076296639442444, 1.8273275375366211, 1.6437...
#
#                                           train_accs  \
# 0  [38.555, 46.4875, 49.235, 51.5025, 53.47, 55.6...
#
#                                             val_accs  train_acc  val_acc  \
# 0  [36.19, 39.83, 44.51, 45.96, 47.96, 43.28, 42....    61.4925    45.58
#
#    test_acc              exp_name  in_dim  out_dim  hid_dim   act  dropout  \
# 0     44.73  exp1_n_layer_hid_dim    3072       10      300  relu      0.2
#
#    use_bn       l2  use_xavier    optim      lr  train_batch_size  n_layer
# 0    True  0.00001        True  RMSprop  0.0015               256        1
# 2 300                                         train_losses  \
# 1  [1.7606302833860847, 1.5190594462072773, 1.409...
#
#                                           val_losses  \
# 1  [1.6915024518966675, 1.6157090783119201, 1.660...
#
#                                           train_accs  \
# 1  [37.515, 46.2375, 49.94, 52.6875, 54.4575, 56....
#
#                                             val_accs  train_acc  val_acc  \
# 1  [41.1, 43.56, 43.29, 47.36, 49.55, 48.87, 50.0...      63.84    50.37
#
#    test_acc              exp_name  in_dim  out_dim  hid_dim   act  dropout  \
# 1     50.41  exp1_n_layer_hid_dim    3072       10      300  relu      0.2
#
#    use_bn       l2  use_xavier    optim      lr  train_batch_size  n_layer
# 1    True  0.00001        True  RMSprop  0.0015               256        2
# 3 300                                         train_losses  \
# 5  [1.771469005353891, 1.511117148551212, 1.39330...
#
#                                           val_losses  \
# 5  [1.7214785099029541, 1.4902804374694825, 1.763...
#
#                                           train_accs  \
# 5  [36.3375, 45.9, 50.0525, 52.72, 55.1975, 57.62...
#
#                                             val_accs  train_acc  val_acc  \
# 5  [38.81, 45.97, 40.39, 44.18, 50.55, 47.27, 45....    65.0575    49.66
#
#    test_acc              exp_name  in_dim  out_dim  hid_dim   act  dropout  \
# 5     49.89  exp1_n_layer_hid_dim    3072       10      300  relu      0.2
#
#    use_bn       l2  use_xavier    optim      lr  train_batch_size  n_layer
# 5    True  0.00001        True  RMSprop  0.0015               256        3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-76dde7af41ff> in <module>
#      24
#      25 df = pd.DataFrame(list_data)
# ---> 26 g = sns.FacetGrid(df, row=var2, col=var1, hue='type', margin_titles=True, sharey=False)
#      27 g = g.map(plt.plot, 'epoch', 'loss', marker='.')
#      28 g.add_legend()
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     321             hue_names = None
#     322         else:
# --> 323             hue_names = categorical_order(data[hue], hue_order)
#     324
#     325         colors = self._get_palette(data, hue, hue_order, palette)
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'type'

# %%
var1 = 'n_layer'
var2 = 'hid_dim'

df = load_exp_result('exp1')
list_v1 = df[var1].unique()
list_v2 = df[var2].unique()
list_data = []

for value1 in list_v1:
    for value2 in list_v2:
        row = df.loc[df[var1]==value1]
        row = row.loc[df[var2]==value2]
        
        train_accs = list(row.train_accs)[0]
        val_accs = list(row.val_accs)[0]
        test_acc = list(row.test_acc)[0]
        
        for epoch, train_acc in enumerate(train_accs):
            list_data.append({'type':'train', 'Acc':train_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})
        for epoch, val_acc in enumerate(val_accs):
            list_data.append({'type':'val', 'Acc':val_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})
        
df = pd.DataFrame(list_data)
g = sns.FacetGrid(df, row=var2, col=var1, hue='type', margin_titles=True, sharey=False)
g = g.map(plt.plot, 'epoch', 'Acc', marker='.')

def show_acc(x, y, metric, **kwargs):
    plt.scatter(x, y, alpha=0.3, s=1)
    metric = "Test Acc: {:1.3f}".format(list(metric.values)[0])
    plt.text(0.05, 0.95, metric,  horizontalalignment='left', verticalalignment='center', transform=plt.gca().transAxes, bbox=dict(facecolor='yellow', alpha=0.5, boxstyle="round,pad=0.1"))
g = g.map(show_acc, 'epoch', 'Acc', 'test_acc')

g.add_legend()
g.fig.suptitle('Train Accuracy vs Val Accuracy')



plt.subplots_adjust(top=0.89)

# %% [markdown]
# ## 모델을 선정 후, 다른 hyperpatameter를 바꿔보자

# %%
# ====== Random Seed Initialization ====== #
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")
args.exp_name = "exp2_lr_dropout"

# ====== Model Capacity ====== #
args.in_dim = 3072
args.out_dim = 10
args.hid_dim = 300
args.act = 'relu'
args.n_layer=3

# ====== Regularization ======= #
#args.dropout = 0.2
args.use_bn = True
args.l2 = 0.00001
args.use_xavier = True

# ====== Optimizer & Training ====== #
args.optim = 'RMSprop' #'RMSprop' #SGD, RMSprop, ADAM...
#args.lr = 0.0015
args.epoch = 10

args.train_batch_size = 256
args.test_batch_size = 1024

# ====== Experiment Variable ====== #
name_var1 = 'lr'
name_var2 = 'dropout'
list_var1 = [0.0001, 0.0005, 0.001, 0.005, 0.01]
list_var2 = [0,0.1,0.2,0.3]


for var1 in list_var1:
    for var2 in list_var2:
        setattr(args, name_var1, var1) ## args.name_var1 = var1 과 같은 말
        setattr(args, name_var2, var2)
        print(args)
                
        setting, result = experiment(partition, deepcopy(args))
        save_exp_result(setting, result)
# Out:
# Namespace(act='relu', dropout=0, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 41.41/43.72, Loss(train/val) 1.67/1.58. Took 3.35 sec
# Epoch 1, Acc(train/val): 49.76/48.21, Loss(train/val) 1.44/1.48. Took 3.34 sec
# Epoch 2, Acc(train/val): 53.83/48.85, Loss(train/val) 1.33/1.45. Took 3.37 sec
# Epoch 3, Acc(train/val): 57.06/49.44, Loss(train/val) 1.24/1.43. Took 3.34 sec
# Epoch 4, Acc(train/val): 59.87/49.69, Loss(train/val) 1.16/1.43. Took 3.36 sec
# Epoch 5, Acc(train/val): 62.40/49.13, Loss(train/val) 1.09/1.45. Took 3.41 sec
# Epoch 6, Acc(train/val): 65.10/49.09, Loss(train/val) 1.02/1.45. Took 3.40 sec
# Epoch 7, Acc(train/val): 67.51/50.59, Loss(train/val) 0.96/1.43. Took 3.36 sec
# Epoch 8, Acc(train/val): 69.73/47.86, Loss(train/val) 0.90/1.55. Took 3.38 sec
# Epoch 9, Acc(train/val): 71.43/47.88, Loss(train/val) 0.85/1.61. Took 3.36 sec
# Namespace(act='relu', dropout=0.1, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 39.53/44.32, Loss(train/val) 1.71/1.58. Took 3.47 sec
# Epoch 1, Acc(train/val): 47.37/46.28, Loss(train/val) 1.50/1.51. Took 3.42 sec
# Epoch 2, Acc(train/val): 50.79/47.60, Loss(train/val) 1.40/1.49. Took 3.36 sec
# Epoch 3, Acc(train/val): 53.59/49.49, Loss(train/val) 1.32/1.42. Took 3.38 sec
# Epoch 4, Acc(train/val): 55.64/51.28, Loss(train/val) 1.26/1.38. Took 3.42 sec
# Epoch 5, Acc(train/val): 58.07/51.40, Loss(train/val) 1.20/1.38. Took 3.38 sec
# Epoch 6, Acc(train/val): 60.10/51.02, Loss(train/val) 1.15/1.39. Took 3.41 sec
# Epoch 7, Acc(train/val): 61.57/50.56, Loss(train/val) 1.10/1.42. Took 3.37 sec
# Epoch 8, Acc(train/val): 63.47/51.69, Loss(train/val) 1.05/1.39. Took 3.54 sec
# Epoch 9, Acc(train/val): 64.99/50.82, Loss(train/val) 1.01/1.41. Took 3.38 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 37.82/43.30, Loss(train/val) 1.76/1.60. Took 3.41 sec
# Epoch 1, Acc(train/val): 45.22/46.09, Loss(train/val) 1.55/1.52. Took 3.41 sec
# Epoch 2, Acc(train/val): 48.85/47.88, Loss(train/val) 1.46/1.47. Took 3.47 sec
# Epoch 3, Acc(train/val): 51.33/48.62, Loss(train/val) 1.39/1.44. Took 3.44 sec
# Epoch 4, Acc(train/val): 53.67/48.65, Loss(train/val) 1.32/1.44. Took 3.35 sec
# Epoch 5, Acc(train/val): 55.02/49.41, Loss(train/val) 1.28/1.42. Took 3.39 sec
# Epoch 6, Acc(train/val): 56.55/51.19, Loss(train/val) 1.23/1.37. Took 3.41 sec
# Epoch 7, Acc(train/val): 58.53/51.19, Loss(train/val) 1.18/1.38. Took 3.39 sec
# Epoch 8, Acc(train/val): 59.91/50.19, Loss(train/val) 1.14/1.42. Took 3.41 sec
# Epoch 9, Acc(train/val): 61.44/48.57, Loss(train/val) 1.10/1.49. Took 3.39 sec
# Namespace(act='relu', dropout=0.3, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 35.16/43.76, Loss(train/val) 1.82/1.62. Took 3.46 sec
# Epoch 1, Acc(train/val): 42.86/46.88, Loss(train/val) 1.62/1.51. Took 3.38 sec
# Epoch 2, Acc(train/val): 46.42/47.50, Loss(train/val) 1.52/1.47. Took 3.42 sec
# Epoch 3, Acc(train/val): 48.31/49.21, Loss(train/val) 1.46/1.44. Took 3.41 sec
# Epoch 4, Acc(train/val): 50.35/49.69, Loss(train/val) 1.40/1.42. Took 3.45 sec
# Epoch 5, Acc(train/val): 52.06/50.20, Loss(train/val) 1.36/1.40. Took 3.37 sec
# Epoch 6, Acc(train/val): 53.65/50.51, Loss(train/val) 1.31/1.40. Took 3.44 sec
# Epoch 7, Acc(train/val): 54.87/51.27, Loss(train/val) 1.27/1.36. Took 3.37 sec
# Epoch 8, Acc(train/val): 56.36/51.01, Loss(train/val) 1.23/1.38. Took 3.40 sec
# Epoch 9, Acc(train/val): 57.74/50.85, Loss(train/val) 1.20/1.38. Took 3.44 sec
# Namespace(act='relu', dropout=0, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0005, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 41.19/42.46, Loss(train/val) 1.65/1.59. Took 3.41 sec
# Epoch 1, Acc(train/val): 50.20/43.95, Loss(train/val) 1.40/1.60. Took 3.38 sec
# Epoch 2, Acc(train/val): 54.55/48.51, Loss(train/val) 1.28/1.46. Took 3.40 sec
# Epoch 3, Acc(train/val): 58.04/49.53, Loss(train/val) 1.18/1.44. Took 3.40 sec
# Epoch 4, Acc(train/val): 61.52/49.36, Loss(train/val) 1.09/1.45. Took 3.41 sec
# Epoch 5, Acc(train/val): 64.57/50.01, Loss(train/val) 1.00/1.46. Took 3.36 sec
# Epoch 6, Acc(train/val): 67.69/48.29, Loss(train/val) 0.92/1.55. Took 3.43 sec
# Epoch 7, Acc(train/val): 70.55/49.75, Loss(train/val) 0.84/1.60. Took 3.38 sec
# Epoch 8, Acc(train/val): 73.24/49.67, Loss(train/val) 0.77/1.63. Took 3.42 sec
# Epoch 9, Acc(train/val): 75.86/49.87, Loss(train/val) 0.69/1.65. Took 3.39 sec
# Namespace(act='relu', dropout=0.1, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0005, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 39.99/41.98, Loss(train/val) 1.69/1.60. Took 3.47 sec
# Epoch 1, Acc(train/val): 48.55/45.23, Loss(train/val) 1.45/1.52. Took 3.44 sec
# Epoch 2, Acc(train/val): 52.74/49.09, Loss(train/val) 1.33/1.45. Took 3.39 sec
# Epoch 3, Acc(train/val): 55.54/50.53, Loss(train/val) 1.25/1.40. Took 3.39 sec
# Epoch 4, Acc(train/val): 58.28/48.68, Loss(train/val) 1.18/1.47. Took 3.39 sec
# Epoch 5, Acc(train/val): 60.73/48.19, Loss(train/val) 1.11/1.49. Took 3.39 sec
# Epoch 6, Acc(train/val): 62.93/48.96, Loss(train/val) 1.05/1.50. Took 3.38 sec
# Epoch 7, Acc(train/val): 65.17/47.39, Loss(train/val) 0.99/1.62. Took 3.38 sec
# Epoch 8, Acc(train/val): 66.82/51.64, Loss(train/val) 0.94/1.51. Took 3.45 sec
# Epoch 9, Acc(train/val): 69.28/50.61, Loss(train/val) 0.87/1.49. Took 3.38 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0005, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 38.83/42.54, Loss(train/val) 1.72/1.64. Took 3.39 sec
# Epoch 1, Acc(train/val): 47.03/47.06, Loss(train/val) 1.48/1.48. Took 3.42 sec
# Epoch 2, Acc(train/val): 50.77/46.27, Loss(train/val) 1.38/1.52. Took 3.40 sec
# Epoch 3, Acc(train/val): 53.62/48.46, Loss(train/val) 1.31/1.45. Took 3.38 sec
# Epoch 4, Acc(train/val): 56.03/49.93, Loss(train/val) 1.24/1.43. Took 3.38 sec
# Epoch 5, Acc(train/val): 57.98/50.80, Loss(train/val) 1.18/1.43. Took 3.41 sec
# Epoch 6, Acc(train/val): 59.97/50.97, Loss(train/val) 1.12/1.40. Took 3.41 sec
# Epoch 7, Acc(train/val): 61.70/45.29, Loss(train/val) 1.07/1.96. Took 3.41 sec
# Epoch 8, Acc(train/val): 63.48/50.14, Loss(train/val) 1.03/1.46. Took 3.40 sec
# Epoch 9, Acc(train/val): 65.12/51.54, Loss(train/val) 0.98/1.43. Took 3.38 sec
# Namespace(act='relu', dropout=0.3, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.0005, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 37.50/40.61, Loss(train/val) 1.75/1.63. Took 3.49 sec
# Epoch 1, Acc(train/val): 45.21/47.31, Loss(train/val) 1.53/1.47. Took 3.46 sec
# Epoch 2, Acc(train/val): 49.13/47.40, Loss(train/val) 1.43/1.48. Took 3.42 sec
# Epoch 3, Acc(train/val): 51.77/46.55, Loss(train/val) 1.36/1.52. Took 3.47 sec
# Epoch 4, Acc(train/val): 53.44/51.18, Loss(train/val) 1.30/1.37. Took 3.41 sec
# Epoch 5, Acc(train/val): 55.67/50.02, Loss(train/val) 1.25/1.40. Took 3.38 sec
# Epoch 6, Acc(train/val): 57.31/46.26, Loss(train/val) 1.20/1.61. Took 3.41 sec
# Epoch 7, Acc(train/val): 59.02/48.74, Loss(train/val) 1.15/1.46. Took 3.39 sec
# Epoch 8, Acc(train/val): 60.34/53.14, Loss(train/val) 1.12/1.35. Took 3.45 sec
# Epoch 9, Acc(train/val): 62.45/52.39, Loss(train/val) 1.06/1.35. Took 3.41 sec
# Namespace(act='relu', dropout=0, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 39.82/39.02, Loss(train/val) 1.69/1.70. Took 3.44 sec
# Epoch 1, Acc(train/val): 48.88/40.18, Loss(train/val) 1.43/1.72. Took 3.44 sec
# Epoch 2, Acc(train/val): 53.14/46.11, Loss(train/val) 1.32/1.50. Took 3.41 sec
# Epoch 3, Acc(train/val): 56.59/45.98, Loss(train/val) 1.22/1.56. Took 3.41 sec
# Epoch 4, Acc(train/val): 60.15/47.09, Loss(train/val) 1.12/1.56. Took 3.38 sec
# Epoch 5, Acc(train/val): 63.08/47.88, Loss(train/val) 1.04/1.54. Took 3.40 sec
# Epoch 6, Acc(train/val): 66.05/49.61, Loss(train/val) 0.96/1.48. Took 3.40 sec
# Epoch 7, Acc(train/val): 68.97/46.52, Loss(train/val) 0.87/1.83. Took 3.40 sec
# Epoch 8, Acc(train/val): 71.92/47.65, Loss(train/val) 0.80/1.74. Took 3.42 sec
# Epoch 9, Acc(train/val): 74.14/47.91, Loss(train/val) 0.73/1.77. Took 3.40 sec
# Namespace(act='relu', dropout=0.1, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 38.62/43.28, Loss(train/val) 1.72/1.59. Took 3.39 sec
# Epoch 1, Acc(train/val): 47.66/45.60, Loss(train/val) 1.46/1.53. Took 3.38 sec
# Epoch 2, Acc(train/val): 51.94/48.11, Loss(train/val) 1.35/1.45. Took 3.39 sec
# Epoch 3, Acc(train/val): 54.90/45.29, Loss(train/val) 1.26/1.55. Took 3.40 sec
# Epoch 4, Acc(train/val): 57.92/47.69, Loss(train/val) 1.19/1.52. Took 3.39 sec
# Epoch 5, Acc(train/val): 60.39/48.28, Loss(train/val) 1.11/1.47. Took 3.39 sec
# Epoch 6, Acc(train/val): 62.72/49.56, Loss(train/val) 1.05/1.49. Took 3.47 sec
# Epoch 7, Acc(train/val): 65.00/50.96, Loss(train/val) 0.99/1.47. Took 3.39 sec
# Epoch 8, Acc(train/val): 66.76/51.53, Loss(train/val) 0.93/1.46. Took 3.38 sec
# Epoch 9, Acc(train/val): 68.91/50.42, Loss(train/val) 0.87/1.57. Took 3.40 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 37.98/40.81, Loss(train/val) 1.74/1.66. Took 3.39 sec
# Epoch 1, Acc(train/val): 46.62/41.40, Loss(train/val) 1.49/1.67. Took 3.46 sec
# Epoch 2, Acc(train/val): 50.16/44.16, Loss(train/val) 1.39/1.55. Took 3.41 sec
# Epoch 3, Acc(train/val): 52.87/43.77, Loss(train/val) 1.32/1.63. Took 3.41 sec
# Epoch 4, Acc(train/val): 55.52/46.65, Loss(train/val) 1.25/1.57. Took 3.36 sec
# Epoch 5, Acc(train/val): 57.42/50.21, Loss(train/val) 1.19/1.43. Took 3.41 sec
# Epoch 6, Acc(train/val): 59.65/50.00, Loss(train/val) 1.13/1.44. Took 3.41 sec
# Epoch 7, Acc(train/val): 61.51/52.89, Loss(train/val) 1.07/1.36. Took 3.41 sec
# Epoch 8, Acc(train/val): 63.59/49.19, Loss(train/val) 1.02/1.51. Took 3.41 sec
# Epoch 9, Acc(train/val): 65.30/48.95, Loss(train/val) 0.97/1.53. Took 3.42 sec
# Namespace(act='relu', dropout=0.3, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.001, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 36.39/42.77, Loss(train/val) 1.77/1.61. Took 3.41 sec
# Epoch 1, Acc(train/val): 45.09/45.20, Loss(train/val) 1.53/1.51. Took 3.39 sec
# Epoch 2, Acc(train/val): 48.96/41.55, Loss(train/val) 1.43/1.65. Took 3.42 sec
# Epoch 3, Acc(train/val): 51.38/47.14, Loss(train/val) 1.36/1.48. Took 3.44 sec
# Epoch 4, Acc(train/val): 53.88/46.63, Loss(train/val) 1.30/1.51. Took 3.45 sec
# Epoch 5, Acc(train/val): 56.06/51.09, Loss(train/val) 1.24/1.39. Took 3.40 sec
# Epoch 6, Acc(train/val): 57.62/49.71, Loss(train/val) 1.19/1.43. Took 3.42 sec
# Epoch 7, Acc(train/val): 59.22/51.99, Loss(train/val) 1.14/1.36. Took 3.38 sec
# Epoch 8, Acc(train/val): 61.10/48.49, Loss(train/val) 1.10/1.49. Took 3.40 sec
# Epoch 9, Acc(train/val): 62.61/50.80, Loss(train/val) 1.05/1.45. Took 3.43 sec
# Namespace(act='relu', dropout=0, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.005, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 32.17/29.52, Loss(train/val) 2.01/2.16. Took 3.39 sec
# Epoch 1, Acc(train/val): 42.80/40.60, Loss(train/val) 1.59/1.68. Took 3.37 sec
# Epoch 2, Acc(train/val): 47.87/40.68, Loss(train/val) 1.46/1.72. Took 3.41 sec
# Epoch 3, Acc(train/val): 51.49/42.46, Loss(train/val) 1.36/1.67. Took 3.40 sec
# Epoch 4, Acc(train/val): 54.16/45.84, Loss(train/val) 1.28/1.58. Took 3.39 sec
# Epoch 5, Acc(train/val): 56.84/44.12, Loss(train/val) 1.21/1.63. Took 3.39 sec
# Epoch 6, Acc(train/val): 58.88/48.34, Loss(train/val) 1.15/1.56. Took 3.37 sec
# Epoch 7, Acc(train/val): 60.95/45.90, Loss(train/val) 1.09/1.62. Took 3.42 sec
# Epoch 8, Acc(train/val): 62.69/48.90, Loss(train/val) 1.04/1.59. Took 3.35 sec
# Epoch 9, Acc(train/val): 64.45/44.36, Loss(train/val) 0.99/1.70. Took 3.47 sec
# Namespace(act='relu', dropout=0.1, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.005, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 32.06/30.54, Loss(train/val) 2.01/2.05. Took 3.40 sec
# Epoch 1, Acc(train/val): 41.89/37.45, Loss(train/val) 1.61/1.77. Took 3.37 sec
# Epoch 2, Acc(train/val): 47.05/39.93, Loss(train/val) 1.48/1.68. Took 3.38 sec
# Epoch 3, Acc(train/val): 49.67/43.62, Loss(train/val) 1.40/1.70. Took 3.41 sec
# Epoch 4, Acc(train/val): 51.90/45.30, Loss(train/val) 1.33/1.54. Took 3.39 sec
# Epoch 5, Acc(train/val): 54.65/44.32, Loss(train/val) 1.26/1.61. Took 3.39 sec
# Epoch 6, Acc(train/val): 56.66/46.83, Loss(train/val) 1.22/1.56. Took 3.39 sec
# Epoch 7, Acc(train/val): 58.57/46.59, Loss(train/val) 1.16/1.54. Took 3.39 sec
# Epoch 8, Acc(train/val): 60.06/43.63, Loss(train/val) 1.11/1.64. Took 3.45 sec
# Epoch 9, Acc(train/val): 61.47/44.63, Loss(train/val) 1.07/1.72. Took 3.39 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.005, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 31.51/30.89, Loss(train/val) 2.03/2.06. Took 3.38 sec
# Epoch 1, Acc(train/val): 41.45/37.80, Loss(train/val) 1.64/1.78. Took 3.46 sec
# Epoch 2, Acc(train/val): 45.57/42.48, Loss(train/val) 1.52/1.65. Took 3.41 sec
# Epoch 3, Acc(train/val): 48.37/43.89, Loss(train/val) 1.44/1.57. Took 3.43 sec
# Epoch 4, Acc(train/val): 51.05/41.36, Loss(train/val) 1.37/1.65. Took 3.44 sec
# Epoch 5, Acc(train/val): 53.21/45.09, Loss(train/val) 1.31/1.55. Took 3.40 sec
# Epoch 6, Acc(train/val): 54.86/48.47, Loss(train/val) 1.26/1.46. Took 3.43 sec
# Epoch 7, Acc(train/val): 56.67/47.93, Loss(train/val) 1.21/1.49. Took 3.44 sec
# Epoch 8, Acc(train/val): 58.10/41.62, Loss(train/val) 1.18/1.87. Took 3.40 sec
# Epoch 9, Acc(train/val): 59.12/47.32, Loss(train/val) 1.15/1.52. Took 3.38 sec
# Namespace(act='relu', dropout=0.3, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.005, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 31.07/36.66, Loss(train/val) 2.03/1.76. Took 3.50 sec
# Epoch 1, Acc(train/val): 40.76/41.59, Loss(train/val) 1.65/1.59. Took 3.38 sec
# Epoch 2, Acc(train/val): 45.45/39.48, Loss(train/val) 1.52/1.71. Took 3.41 sec
# Epoch 3, Acc(train/val): 48.37/38.91, Loss(train/val) 1.45/1.71. Took 3.44 sec
# Epoch 4, Acc(train/val): 50.40/44.32, Loss(train/val) 1.39/1.56. Took 3.39 sec
# Epoch 5, Acc(train/val): 51.90/47.16, Loss(train/val) 1.35/1.48. Took 3.41 sec
# Epoch 6, Acc(train/val): 54.21/45.59, Loss(train/val) 1.28/1.60. Took 3.50 sec
# Epoch 7, Acc(train/val): 55.71/47.18, Loss(train/val) 1.25/1.53. Took 3.38 sec
# Epoch 8, Acc(train/val): 57.04/50.00, Loss(train/val) 1.21/1.44. Took 3.44 sec
# Epoch 9, Acc(train/val): 58.32/49.82, Loss(train/val) 1.17/1.43. Took 3.39 sec
# Namespace(act='relu', dropout=0, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.01, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 30.55/29.91, Loss(train/val) 2.28/2.28. Took 3.43 sec
# Epoch 1, Acc(train/val): 40.12/34.67, Loss(train/val) 1.67/2.05. Took 3.40 sec
# Epoch 2, Acc(train/val): 44.49/38.63, Loss(train/val) 1.55/1.91. Took 3.46 sec
# Epoch 3, Acc(train/val): 47.50/37.23, Loss(train/val) 1.45/1.91. Took 3.49 sec
# Epoch 4, Acc(train/val): 48.60/37.92, Loss(train/val) 1.44/1.82. Took 3.39 sec
# Epoch 5, Acc(train/val): 50.60/40.75, Loss(train/val) 1.37/1.74. Took 3.38 sec
# Epoch 6, Acc(train/val): 52.20/42.80, Loss(train/val) 1.33/1.64. Took 3.39 sec
# Epoch 7, Acc(train/val): 54.17/40.26, Loss(train/val) 1.28/1.74. Took 3.44 sec
# Epoch 8, Acc(train/val): 55.20/42.04, Loss(train/val) 1.25/1.66. Took 3.40 sec
# Epoch 9, Acc(train/val): 55.89/45.62, Loss(train/val) 1.24/1.57. Took 3.44 sec
# Namespace(act='relu', dropout=0.1, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.01, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 29.01/29.33, Loss(train/val) 2.29/2.13. Took 3.42 sec
# Epoch 1, Acc(train/val): 39.16/36.13, Loss(train/val) 1.68/1.90. Took 3.44 sec
# Epoch 2, Acc(train/val): 44.37/33.74, Loss(train/val) 1.55/2.07. Took 3.46 sec
# Epoch 3, Acc(train/val): 47.00/41.44, Loss(train/val) 1.47/1.62. Took 3.41 sec
# Epoch 4, Acc(train/val): 48.87/42.24, Loss(train/val) 1.43/1.65. Took 3.48 sec
# Epoch 5, Acc(train/val): 51.01/41.78, Loss(train/val) 1.37/1.71. Took 3.40 sec
# Epoch 6, Acc(train/val): 52.55/41.82, Loss(train/val) 1.32/1.69. Took 3.40 sec
# Epoch 7, Acc(train/val): 53.66/44.70, Loss(train/val) 1.29/1.55. Took 3.44 sec
# Epoch 8, Acc(train/val): 54.76/46.99, Loss(train/val) 1.26/1.49. Took 3.44 sec
# Epoch 9, Acc(train/val): 55.92/45.86, Loss(train/val) 1.24/1.58. Took 3.43 sec
# Namespace(act='relu', dropout=0.2, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.01, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 28.88/32.99, Loss(train/val) 2.31/1.86. Took 3.37 sec
# Epoch 1, Acc(train/val): 38.86/38.75, Loss(train/val) 1.69/1.69. Took 3.38 sec
# Epoch 2, Acc(train/val): 43.33/37.72, Loss(train/val) 1.57/1.80. Took 3.40 sec
# Epoch 3, Acc(train/val): 45.40/39.11, Loss(train/val) 1.52/1.71. Took 3.44 sec
# Epoch 4, Acc(train/val): 48.23/42.33, Loss(train/val) 1.45/1.69. Took 3.39 sec
# Epoch 5, Acc(train/val): 50.45/39.23, Loss(train/val) 1.39/1.82. Took 3.43 sec
# Epoch 6, Acc(train/val): 51.52/40.22, Loss(train/val) 1.36/1.76. Took 3.40 sec
# Epoch 7, Acc(train/val): 52.45/47.38, Loss(train/val) 1.33/1.53. Took 3.38 sec
# Epoch 8, Acc(train/val): 53.89/43.36, Loss(train/val) 1.30/1.61. Took 3.39 sec
# Epoch 9, Acc(train/val): 54.58/39.19, Loss(train/val) 1.28/1.87. Took 3.41 sec
# Namespace(act='relu', dropout=0.3, epoch=10, exp_name='exp2_lr_dropout', hid_dim=300, in_dim=3072, l2=1e-05, lr=0.01, n_layer=3, optim='RMSprop', out_dim=10, test_batch_size=1024, train_batch_size=256, use_bn=True, use_xavier=True)
# Epoch 0, Acc(train/val): 28.50/33.73, Loss(train/val) 2.33/1.85. Took 3.37 sec
# Epoch 1, Acc(train/val): 38.05/38.16, Loss(train/val) 1.72/1.72. Took 3.38 sec
# Epoch 2, Acc(train/val): 42.70/39.60, Loss(train/val) 1.59/1.71. Took 3.39 sec
# Epoch 3, Acc(train/val): 45.33/37.31, Loss(train/val) 1.52/1.77. Took 3.45 sec
# Epoch 4, Acc(train/val): 47.57/38.74, Loss(train/val) 1.46/1.78. Took 3.40 sec
# Epoch 5, Acc(train/val): 48.78/44.27, Loss(train/val) 1.43/1.58. Took 3.40 sec
# Epoch 6, Acc(train/val): 50.39/40.57, Loss(train/val) 1.39/1.67. Took 3.42 sec
# Epoch 7, Acc(train/val): 51.76/40.63, Loss(train/val) 1.36/1.72. Took 3.40 sec
# Epoch 8, Acc(train/val): 51.70/45.18, Loss(train/val) 1.36/1.54. Took 3.42 sec
# Epoch 9, Acc(train/val): 53.49/42.82, Loss(train/val) 1.31/1.71. Took 3.41 sec

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

df = load_exp_result('exp2')

fig, ax = plt.subplots(1, 3)
fig.set_size_inches(15, 6)
sns.set_style("darkgrid", {"axes.facecolor": ".9"})

sns.barplot(x='lr', y='train_acc', hue='dropout', data=df, ax=ax[0])
sns.barplot(x='lr', y='val_acc', hue='dropout', data=df, ax=ax[1])
sns.barplot(x='lr', y='test_acc', hue='dropout', data=df, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='lr', ylabel='test_acc'>

# %%
var1 = 'lr'
var2 = 'dropout'

df = load_exp_result('exp2')
list_v1 = df[var1].unique()
list_v2 = df[var2].unique()
print(list_v1, list_v2)
list_data = []

for value1 in list_v1:
    for value2 in list_v2:
        row = df.loc[df[var1]==value1]
        row = row.loc[df[var2]==value2]
        
        
        train_losses = list(row.train_losses)[0]
        val_losses = list(row.val_losses)[0]
        
        for epoch, train_loss in enumerate(train_losses):
            list_data.append({'type':'train', 'loss':train_loss, 'epoch':epoch, var1:value1, var2:value2})
        for epoch, val_loss in enumerate(val_losses):
            list_data.append({'type':'val', 'loss':val_loss, 'epoch':epoch, var1:value1, var2:value2})
        
df = pd.DataFrame(list_data)
g = sns.FacetGrid(df, row=var2, col=var1, hue='type', margin_titles=True, sharey=False)
g = g.map(plt.plot, 'epoch', 'loss', marker='.')
g.add_legend()
g.fig.suptitle('Train loss vs Val loss')
plt.subplots_adjust(top=0.89)
# Out:
# [0.001  0.0001 0.0005 0.01   0.005 ] [0.2 0.3 0.1 0. ]

# %%
var1 = 'lr'
var2 = 'dropout'

df = load_exp_result('exp2')
list_v1 = df[var1].unique()
list_v2 = df[var2].unique()
list_data = []

for value1 in list_v1:
    for value2 in list_v2:
        row = df.loc[df[var1]==value1]
        row = row.loc[df[var2]==value2]
        
        train_accs = list(row.train_accs)[0]
        val_accs = list(row.val_accs)[0]
        test_acc = list(row.test_acc)[0]
        
        for epoch, train_acc in enumerate(train_accs):
            list_data.append({'type':'train', 'Acc':train_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})
        for epoch, val_acc in enumerate(val_accs):
            list_data.append({'type':'val', 'Acc':val_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})
        
df = pd.DataFrame(list_data)
g = sns.FacetGrid(df, row=var2, col=var1, hue='type', margin_titles=True, sharey=False)
g = g.map(plt.plot, 'epoch', 'Acc', marker='.')

def show_acc(x, y, metric, **kwargs):
    plt.scatter(x, y, alpha=0.3, s=1)
    metric = "Test Acc: {:1.3f}".format(list(metric.values)[0])
    plt.text(0.05, 0.95, metric,  horizontalalignment='left', verticalalignment='center', transform=plt.gca().transAxes, bbox=dict(facecolor='yellow', alpha=0.5, boxstyle="round,pad=0.1"))
g = g.map(show_acc, 'epoch', 'Acc', 'test_acc')

g.add_legend()
g.fig.suptitle('Train Accuracy vs Val Accuracy')



plt.subplots_adjust(top=0.89)
